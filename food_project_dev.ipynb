# %%
import sqlite3
import pandas as pd

# %%
pandas.read_csv(csvfile.to_sql('table_1', conn, if_exists='append', index=False)

# %%
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection("sqlite/db/pythonsqlite.db")
# Out:
# 2.6.0

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn

# %%
def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

# %%
def main():
    database = "sqlite/db/pythonsqlite.db"

    sql_create_food_prices_table = """CREATE TABLE IF NOT EXISTS food_prices (
                                    id integer PRIMARY KEY,
                                    cm_name text NOT NULL,
                                    adm0_name text NOT NULL,
                                    um_name text NOT NULL,
                                    mp_year text NOT NULL,
                                    mp_price integer NOT NULL
                                );"""

    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create food_prices table
        create_table(conn, sql_create_food_prices_table)

    else:
        print("Error! cannot create the database connection.")

# %%
if __name__ == '__main__':
    main()

# %%
con = sqlite3.connect("sqlite/db/pythonsqlite.db")

# %%
df1 = pd.read_csv('wfpvam_foodprices.csv')

# %%
df1 = df1[['cm_name', 'adm0_name', 'um_name', 'mp_year', 'mp_price']]

# %%
df1
# Out:
#                                      cm_name    adm0_name um_name  mp_year  \
# 0                             Bread - Retail  Afghanistan      KG     2014
# 1                             Bread - Retail  Afghanistan      KG     2014
# 2                             Bread - Retail  Afghanistan      KG     2014
# 3                             Bread - Retail  Afghanistan      KG     2014
# 4                             Bread - Retail  Afghanistan      KG     2014
# ...                                      ...          ...     ...      ...
# 1764351    Sugar (white, fortified) - Retail     Zimbabwe      KG     2017
# 1764352                       Beans - Retail     Zimbabwe      KG     2018
# 1764353                       Maize - Retail     Zimbabwe      KG     2018
# 1764354             Oil (vegetable) - Retail     Zimbabwe       L     2018
# 1764355  Maize meal (white, roller) - Retail     Zimbabwe      KG     2018
#
#          mp_price
# 0           50.00
# 1           50.00
# ...

# %%
# df.to_sql('food_prices', con, if_exists='replace', index=False)

# %%
con = sqlite3.connect("sqlite/db/pythonsqlite.db")

# %%
df = pd.read_sql_query("SELECT * from food_prices", con)

# %%
df
# Out:
#                                      cm_name    adm0_name um_name  mp_year  \
# 0                             Bread - Retail  Afghanistan      KG     2014
# 1                             Bread - Retail  Afghanistan      KG     2014
# 2                             Bread - Retail  Afghanistan      KG     2014
# 3                             Bread - Retail  Afghanistan      KG     2014
# 4                             Bread - Retail  Afghanistan      KG     2014
# ...                                      ...          ...     ...      ...
# 1311188     Wheat flour (fortified) - Retail     Zimbabwe      KG     2017
# 1311189    Sugar (white, fortified) - Retail     Zimbabwe      KG     2017
# 1311190                       Beans - Retail     Zimbabwe      KG     2018
# 1311191                       Maize - Retail     Zimbabwe      KG     2018
# 1311192  Maize meal (white, roller) - Retail     Zimbabwe      KG     2018
#
#          mp_price
# 0           50.00
# 1           50.00
# ...

# %%
df.columns
# Out:
# Index(['cm_name', 'adm0_name', 'um_name', 'mp_year', 'mp_price'], dtype='object')

# %%
df = df.loc[df['um_name'] == 'KG']

# %%
df['cm_name'].value_counts()[:5].index.tolist()
# Out:
# ['Millet - Retail',
#  'Rice (imported) - Retail',
#  'Maize - Retail',
#  'Sorghum - Retail',
#  'Wheat flour - Retail']

# %%
mask = df['cm_name'].isin(df['cm_name'].value_counts()[:5].index.tolist())

# %%
df.loc[mask]
# Out:
#                       cm_name    adm0_name um_name  mp_year  mp_price
# 2425     Wheat flour - Retail  Afghanistan      KG     2000     10.06
# 2426     Wheat flour - Retail  Afghanistan      KG     2000      9.88
# 2427     Wheat flour - Retail  Afghanistan      KG     2000     10.23
# 2428     Wheat flour - Retail  Afghanistan      KG     2000     13.90
# 2429     Wheat flour - Retail  Afghanistan      KG     2000     12.69
# ...                       ...          ...     ...      ...       ...
# 1311178        Maize - Retail     Zimbabwe      KG     2018      0.29
# 1311182        Maize - Retail     Zimbabwe      KG     2017      0.23
# 1311183      Sorghum - Retail     Zimbabwe      KG     2017      0.17
# 1311184       Millet - Retail     Zimbabwe      KG     2017      0.17
# 1311191        Maize - Retail     Zimbabwe      KG     2018      0.40
#
# [220287 rows x 5 columns]

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# anyio                         2.0.2
# argon2-cffi                   20.1.0
# asgiref                       3.2.10
# async-generator               1.10
# attrs                         20.3.0
# Automat                       20.2.0
# Babel                         2.9.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.1
# bleach                        3.2.1
# bokeh                         2.2.3
# brotlipy                      0.7.0
# certifi                       2020.12.5
# cffi                          1.14.4
# chardet                       4.0.0
# colorcet                      2.0.6
# constantly                    15.1.0
# cryptography                  3.3.1
# cycler                        0.10.0
# decorator                     4.4.2
# defusedxml                    0.6.0
# Django                        3.1.2
# entrypoints                   0.3
# ...

# %%
df
# Out:
#          cm_name    adm0_name um_name  mp_year  mp_price
# 0            NaN  Afghanistan      KG     2014     50.00
# 1            NaN  Afghanistan      KG     2014     50.00
# 2            NaN  Afghanistan      KG     2014     50.00
# 3            NaN  Afghanistan      KG     2014     50.00
# 4            NaN  Afghanistan      KG     2014     50.00
# ...          ...          ...     ...      ...       ...
# 1311188      NaN     Zimbabwe      KG     2017      1.50
# 1311189      NaN     Zimbabwe      KG     2017      1.50
# 1311190      NaN     Zimbabwe      KG     2018      2.80
# 1311191      NaN     Zimbabwe      KG     2018      0.40
# 1311192      NaN     Zimbabwe      KG     2018      0.55
#
# [1311193 rows x 5 columns]

# %%
t = df.loc[df['mp_year'] == 2020]

# %%
t
# Out:
#                                         cm_name    adm0_name um_name  mp_year  \
# 69                               Bread - Retail  Afghanistan      KG     2020
# 70                               Bread - Retail  Afghanistan      KG     2020
# 71                               Bread - Retail  Afghanistan      KG     2020
# 72                               Bread - Retail  Afghanistan      KG     2020
# 275                              Wheat - Retail  Afghanistan      KG     2020
# ...                                         ...          ...     ...      ...
# 1307709  Maize meal (white, breakfast) - Retail       Zambia      KG     2020
# 1307710  Maize meal (white, breakfast) - Retail       Zambia      KG     2020
# 1307711  Maize meal (white, breakfast) - Retail       Zambia      KG     2020
# 1307712  Maize meal (white, breakfast) - Retail       Zambia      KG     2020
# 1307713  Maize meal (white, breakfast) - Retail       Zambia      KG     2020
#
#          mp_price
# ...

# %%
t = t.loc[t['cm_name'] == 'Bread - Retail']

# %%
t = t.sort_values('mp_price')

# %%
t
# Out:
#                 cm_name           adm0_name um_name  mp_year  mp_price
# 1094667  Bread - Retail  State of Palestine      KG     2020      2.30
# 1094665  Bread - Retail  State of Palestine      KG     2020      2.30
# 1094666  Bread - Retail  State of Palestine      KG     2020      2.30
# 1094668  Bread - Retail  State of Palestine      KG     2020      2.30
# 1094660  Bread - Retail  State of Palestine      KG     2020      2.33
# ...                 ...                 ...     ...      ...       ...
# 311553   Bread - Retail               Congo      KG     2020   1183.00
# 310826   Bread - Retail               Congo      KG     2020   1188.00
# 311551   Bread - Retail               Congo      KG     2020   1192.00
# 310134   Bread - Retail               Congo      KG     2020   1194.00
# 311549   Bread - Retail               Congo      KG     2020   1271.00
#
# [718 rows x 5 columns]

# %%
t = t.drop_duplicates(subset=['adm0_name'], keep='first')

# %%
t
# Out:
#                 cm_name           adm0_name um_name  mp_year  mp_price
# 1094667  Bread - Retail  State of Palestine      KG     2020      2.30
# 853662   Bread - Retail                Peru      KG     2020      6.78
# 376061   Bread - Retail              Gambia      KG     2020     14.00
# 2413     Bread - Retail         Afghanistan      KG     2020     29.41
# 520333   Bread - Retail          Kyrgyzstan      KG     2020     43.98
# 9392     Bread - Retail           Argentina      KG     2020    111.25
# 312249   Bread - Retail               Congo      KG     2020    760.00

# %%
t = t.nsmallest(5, ['mp_price'])

# %%
'Bread - Retail'

# %%
df
# Out:
#                                      cm_name    adm0_name um_name  mp_year  \
# 0                             Bread - Retail  Afghanistan      KG     2014
# 1                             Bread - Retail  Afghanistan      KG     2014
# 2                             Bread - Retail  Afghanistan      KG     2014
# 3                             Bread - Retail  Afghanistan      KG     2014
# 4                             Bread - Retail  Afghanistan      KG     2014
# ...                                      ...          ...     ...      ...
# 1764350     Wheat flour (fortified) - Retail     Zimbabwe      KG     2017
# 1764351    Sugar (white, fortified) - Retail     Zimbabwe      KG     2017
# 1764352                       Beans - Retail     Zimbabwe      KG     2018
# 1764353                       Maize - Retail     Zimbabwe      KG     2018
# 1764355  Maize meal (white, roller) - Retail     Zimbabwe      KG     2018
#
#          mp_price
# 0           50.00
# 1           50.00
# ...

# %%
len(a['cm_name'].unique())
# Out:
# 625

# %%
a = df['um_name'].unique()

# %%
a
# Out:
# array(['KG', 'Day', 'Unit', 'L', 'USD/LCU', '30 pcs', '500 G', '125 G',
#        'Packet', '900 G', '50 Pounds', '100 KG', '46 KG', '11.5 KG',
#        'Pound', 'Cuartilla', 'Libra', '5 L', '10 pcs', '90 KG', '1.5 L',
#        '400 G', 'Sack', 'Package', 'Head', 'MT', '85 G', 'Gallon',
#        '380 G', '500 ML', 'Month', 'Course', '50 KG', '100 Pounds',
#        '168 G', '45 KG', '70 G', '200 G', '68 KG', '109 KG', '91 KG',
#        '93 KG', '10 KG', 'Bunch', '250 KG', '100 Tubers', '73 KG',
#        '84 KG', '52 KG', '27 KG', '20 KG', '16 KG', '650 G', '750 ML',
#        '115 G', '360 pcs', '50 pcs', '100 pcs', 'Marmite', '350 G',
#        '385 G', '1.8 KG', 'Cylinder', '4 pcs', '150 ml', '5 KG', '2 KG',
#        '1.8 L', '170 G', '1.5 KG', '300 G', '0.8 KG', '160 G', '750 G',
#        '12.5 KG', '200 ML', '150 G', '20 L', '1.3 KG', '185 G', 'Loaf',
#        '2.25 KG', '5 pcs', '250 G', '11 KG', 'Brush', '100 ML', 'Bar',
# ...

# %%
list(df['cm_name'].unique())
# Out:
# ['Bread - Retail',
#  'Wheat - Retail',
#  'Rice (low quality) - Retail',
#  'Oil (cooking) - Retail',
#  'Sugar - Retail',
#  'Pulses - Retail',
#  'Wheat flour (high quality) - Retail',
#  'Salt - Retail',
#  'Rice (high quality) - Retail',
#  'Wheat flour (low quality) - Retail',
#  'Wheat flour - Retail',
#  'Rice - Retail',
#  'Beans (white) - Retail',
#  'Potatoes - Retail',
#  'Meat (chicken) - Retail',
#  'Lentils - Retail',
#  'Tomatoes - Retail',
#  'Meat (beef) - Retail',
#  'Carrots - Retail',
#  'Onions - Retail',
#  'Bananas - Retail',
#  'Tea - Retail',
#  'Apples - Retail',
#  'Oranges - Retail',
#  'Meat (camel) - Retail',
#  'Cassava flour - Retail',
#  'Salt (iodised) - Retail',
#  'Sugar (white) - Retail',
#  'Rice (white, imported) - Retail',
#  'Maize meal (yellow) - Retail',
#  'Fish (mackerel, dry) - Retail',
#  'Beans (kidney, pinto) - Retail',
#  'Wheat flour - Wholesale',
#  'Wheat - Wholesale',
#  'Rice (white) - Retail',
#  'Maize (yellow) - Wholesale',
# ...

# %%
len(b)
# Out:
# 829

# %%
c = df['adm0_name'].unique()

# %%
len(c)
# Out:
# 98

# %%
d = df['mp_year'].unique()

# %%
d
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2000, 2001, 2002, 1996,
#        1997, 1998, 1999, 1994, 1995, 1992, 1993, 1990, 1991])
